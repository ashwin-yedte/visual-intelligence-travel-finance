# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwin-yedte/visual-intelligence-travel-finance/blob/main/Data_Preparation_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # =================================================================
#  COMPLETE VISUAL INTELLIGENCE DATA COLLECTION PIPELINE for Indian Destination Dataset
#
#  Phase 1: Identify the Curated Destinations, Pre-Organized by state and theme
#
#  Phase 2: Downloads Images from Unsplash
#
#  Phase 3: For each destination, searches for matching images
#
#  Phase 4: Validates URLs before downloading
#
#  Phase 5: Organizes: theme/state/destination/
#
# #
# #=================================================================

# %% [markdown]
# # =================================================================
#  STEP 1: SETUP AND MOUNT GOOGLE DRIVE
# # =================================================================

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

BASE_PATH = '/content/drive/MyDrive/visual-intelligence-travel-finance'
LANDMARKS_PATH = f'{BASE_PATH}/data/landmarks'
CACHE_PATH = f'{BASE_PATH}/cache'

os.makedirs(LANDMARKS_PATH, exist_ok=True)
os.makedirs(CACHE_PATH, exist_ok=True)

print("="*80)
print("SETUP COMPLETE")
print("="*80)
print(f"Base path: {BASE_PATH}")
print(f"Landmarks path: {LANDMARKS_PATH}")
print(f"Cache path: {CACHE_PATH}")
print("="*80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ================================================================================
# SETUP COMPLETE
# ================================================================================
# Base path: /content/drive/MyDrive/visual-intelligence-travel-finance
# Landmarks path: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks
# Cache path: /content/drive/MyDrive/visual-intelligence-travel-finance/cache
# ================================================================================

# %% [markdown]
# # =================================================================
#  STEP 2: INSTALL PACKAGES
# # =================================================================

# %%
# !pip install -q requests pillow tqdm

import requests
from PIL import Image
import io
import time
from tqdm import tqdm
import json
import re

print("="*80)
print("PACKAGES INSTALLED")
print("="*80)
# Out:
# ================================================================================
# PACKAGES INSTALLED
# ================================================================================

# %% [markdown]
# # =================================================================
#  STEP 3: UNSPLASH API CONFIGURATION
# # =================================================================

# %%
UNSPLASH_ACCESS_KEY = "63qO1DVp5p0_xaGj4bmRmtjAfF4Z1E1yDUs1B1SD1B4"

# %% [markdown]
# # =================================================================
#  STEP 4: LOAD CURATED INDIAN DESTINATIONS DATASET
# # =================================================================

# %%
# ============================================================================
# CELL 4: CURATED INDIAN DESTINATIONS DATASET (UPDATED FOR CLIP)
# ============================================================================

INDIAN_DESTINATIONS = {
  "Beach": {
    "goa": [
      "Calangute Beach","Baga Beach","Anjuna Beach",
      "Vagator Beach","Palolem Beach","Colva Beach",
      "Morjim Beach","Arambol Beach","Candolim Beach",
      "Benaulim Beach","Agonda Beach","Ashwem Beach",
      "Mandrem Beach","Sinquerim Beach","Miramar Beach",
      "Dona Paula Beach","Bogmalo Beach","Butterfly Beach",
      "Kakolem Beach","Betalbatim Beach"
    ],
    "kerala": [
      "Kovalam Beach", "Varkala Beach", "Cherai Beach", "Marari Beach",
      "Bekal Beach", "Muzhappilangad Beach", "Kappad Beach",
      "Shanghumukham Beach", "Alappuzha Beach", "Payyambalam Beach",
      "Kollam Beach", "Kozhikode Beach", "Thirumullavaram Beach",
      "Kappil Beach", "Ezhimala Beach"
    ],
    "maharashtra": [
      "Alibaug Beach", "Kashid Beach", "Ganpatipule Beach", "Tarkarli Beach",
      "Juhu Beach", "Girgaon Chowpatty", "Aksa Beach", "Murud Beach",
      "Diveagar Beach", "Harihareshwar Beach", "Ratnagiri Beach",
      "Revdanda Beach", "Kelshi Beach", "Bordi Beach", "Dahanu Beach",
      "Nagaon Beach", "Versova Beach", "Manori Beach"
    ],
    "tamil_nadu": [
      "Marina Beach", "Mahabalipuram Beach", "Kanyakumari Beach",
      "Rameswaram Beach", "Covelong Beach", "Elliots Beach",
      "Besant Nagar Beach", "Dhanushkodi Beach", "Thiruvanmiyur Beach",
      "Kadalur Beach", "Pondicherry Beach", "Tuticorin Beach"
    ],
    "karnataka": [
      "Gokarna Beach", "Malpe Beach", "Karwar Beach", "Murudeshwar Beach",
      "Kaup Beach", "Panambur Beach", "Om Beach", "Kudle Beach",
      "Half Moon Beach", "Paradise Beach", "Tannirbhavi Beach",
      "Surathkal Beach", "Ullal Beach", "Someshwara Beach"
    ],
    "andhra_pradesh": [
      "Rishikonda Beach", "Ramakrishna Beach", "Yarada Beach",
      "Bheemunipatnam Beach", "Vodarevu Beach", "Suryalanka Beach",
      "Mypadu Beach", "Manginapudi Beach"
    ],
    "odisha": [
      "Puri Beach", "Chandrabhaga Beach", "Gopalpur Beach",
      "Astaranga Beach", "Paradeep Beach", "Balasore Beach",
      "Rushikulya Beach", "Satapada Beach"
    ],
    "west_bengal": [
      "Digha Beach", "Mandarmani Beach", "Bakkhali Beach",
      "Shankarpur Beach", "Tajpur Beach", "Henry Island Beach",
      "Talsari Beach", "Sagar Island Beach"
    ],
    "gujarat": [
      "Mandvi Beach", "Diu Beach", "Dwarka Beach", "Chorwad Beach",
      "Ahmedpur Mandvi Beach", "Tithal Beach", "Ubharat Beach",
      "Gopnath Beach", "Veraval Beach"
    ],
    "puducherry": [
      "Paradise Beach", "Auroville Beach", "Promenade Beach",
      "Serenity Beach", "Karaikal Beach", "Mahe Beach"
    ],
    "lakshadweep": [
      "Agatti Beach", "Kadmat Beach", "Bangaram Beach",
      "Kavaratti Beach", "Minicoy Beach", "Kalpeni Beach"
    ],
    "andaman_and_nicobar": [
      "Radhanagar Beach", "Corbyn's Cove Beach", "Elephant Beach",
      "Vijaynagar Beach", "Bharatpur Beach", "Kalapathar Beach",
      "Wandoor Beach", "Sitapur Beach", "Laxmanpur Beach"
    ]
  },
  "Temple": {
    "tamil_nadu": [
      "Meenakshi Temple Madurai", "Brihadeeswarar Temple Thanjavur",
      "Kapaleeshwarar Temple Chennai", "Ramanathaswamy Temple Rameswaram",
      "Ekambareswarar Temple Kanchipuram", "Kailasanathar Temple Kanchipuram",
      "Airavatesvara Temple Darasuram", "Thillai Nataraja Temple Chidambaram",
      "Ranganathaswamy Temple Srirangam", "Tirupati Balaji Temple"
    ],
    "kerala": [
      "Padmanabhaswamy Temple Thiruvananthapuram", "Guruvayur Temple",
      "Sabarimala Temple", "Ambalapuzha Temple", "Ettumanoor Temple",
      "Vadakkunnathan Temple Thrissur", "Attukal Temple"
    ],
    "karnataka": [
      "Virupaksha Temple Hampi", "Chennakesava Temple Belur",
      "Hoysaleswara Temple Halebidu", "Murudeshwar Temple",
      "Chamundeshwari Temple Mysore", "Udupi Krishna Temple",
      "Gokarneshwara Temple"
    ],
    "andhra_pradesh": [
      "Tirumala Venkateswara Temple", "Simhachalam Temple Visakhapatnam",
      "Srikalahasti Temple", "Kanaka Durga Temple Vijayawada",
      "Bhadrachalam Temple"
    ],
    "rajasthan": [
      "Brahma Temple Pushkar", "Dilwara Temples Mount Abu",
      "Karni Mata Temple Bikaner", "Eklingji Temple Udaipur"
    ],
    "maharashtra": [
      "Siddhivinayak Temple Mumbai", "Mahalakshmi Temple Mumbai",
      "Trimbakeshwar Temple Nashik", "Bhimashankar Temple",
      "Aundha Nagnath Temple"
    ],
    "madhya_pradesh": [
      "Khajuraho Temples", "Mahakaleshwar Temple Ujjain",
      "Omkareshwar Temple", "Bhojpur Temple"
    ],
    "uttar_pradesh": [
      "Kashi Vishwanath Temple Varanasi", "Krishna Janmabhoomi Mathura",
      "Banke Bihari Temple Vrindavan", "Hanuman Temple Allahabad"
    ],
    "uttarakhand": [
      "Kedarnath Temple", "Badrinath Temple", "Gangotri Temple",
      "Yamunotri Temple", "Neelkanth Mahadev Temple"
    ]
  },
  "Fort": {
    "rajasthan": [
      "Amber Fort Jaipur", "Mehrangarh Fort Jodhpur", "Jaisalmer Fort",
      "Chittorgarh Fort", "Kumbhalgarh Fort", "Ranthambore Fort",
      "Nahargarh Fort Jaipur", "Jaigarh Fort", "Gagron Fort"
    ],
    "maharashtra": [
      "Raigad Fort", "Pratapgad Fort", "Sinhagad Fort", "Shivneri Fort",
      "Rajgad Fort", "Panhala Fort", "Daulatabad Fort", "Torna Fort",
      "Lohagad Fort", "Vijaydurg Fort"
    ],
    "karnataka": [
      "Chitradurga Fort", "Bangalore Fort", "Belgaum Fort", "Bidar Fort",
      "Mirjan Fort", "Nandi Hills Fort"
    ],
    "madhya_pradesh": [
      "Gwalior Fort", "Mandu Fort", "Asirgarh Fort", "Raisen Fort"
    ],
    "telangana": [
      "Golconda Fort Hyderabad", "Warangal Fort", "Bhongir Fort"
    ],
    "delhi": [
      "Red Fort", "Purana Qila", "Tughlaqabad Fort"
    ],
    "gujarat": [
      "Diu Fort", "Champaner Fort", "Uparkot Fort Junagadh"
    ],
    "tamil_nadu": [
      "Gingee Fort", "Vellore Fort", "Dindigul Fort"
    ]
  },
  "Waterfall": {
    "karnataka": [
      "Jog Falls", "Abbey Falls", "Shivanasamudra Falls", "Kunchikal Falls",
      "Iruppu Falls", "Hebbe Falls", "Gokak Falls", "Unchalli Falls",
      "Magod Falls"
    ],
    "kerala": [
      "Athirappilly Falls", "Vazhachal Falls", "Meenmutty Falls",
      "Soochipara Falls", "Palaruvi Falls", "Thommankuthu Falls",
      "Aruvikkuzhi Falls", "Lakkom Falls"
    ],
    "maharashtra": [
      "Dudhsagar Falls", "Lingmala Falls", "Kune Falls", "Thoseghar Falls",
      "Pandavkada Falls", "Vajrai Falls"
    ],
    "madhya_pradesh": [
      "Dhuandhar Falls", "Bahuti Falls", "Patalpani Falls",
      "Rajat Prapat Falls"
    ],
    "meghalaya": [
      "Nohkalikai Falls", "Seven Sisters Falls", "Elephant Falls",
      "Kynrem Falls", "Wei Sawdong Falls"
    ],
    "jharkhand": [
      "Hundru Falls", "Jonha Falls", "Dassam Falls", "Hirni Falls"
    ],
    "chhattisgarh": [
      "Chitrakote Falls", "Tirathgarh Falls", "Amrit Dhara Falls"
    ],
    "uttarakhand": [
      "Kempty Falls", "Tiger Falls", "Bhatta Falls", "Vasudhara Falls"
    ]
  },
  "HillStation": {
    "himachal_pradesh": [
      "Shimla", "Manali", "Dharamshala", "Dalhousie", "Kasauli",
      "Kullu", "Chamba", "Kufri", "Palampur"
    ],
    "uttarakhand": [
      "Mussoorie", "Nainital", "Rishikesh", "Almora", "Ranikhet",
      "Lansdowne", "Kausani", "Auli"
    ],
    "tamil_nadu": [
      "Ooty", "Kodaikanal", "Coonoor", "Yercaud", "Yelagiri"
    ],
    "kerala": [
      "Munnar", "Wayanad", "Thekkady", "Ponmudi", "Vagamon",
      "Idukki", "Vythiri"
    ],
    "karnataka": [
      "Coorg", "Chikmagalur", "Sakleshpur", "Agumbe", "Kudremukh"
    ],
    "maharashtra": [
      "Mahabaleshwar", "Lonavala", "Matheran", "Panchgani",
      "Khandala", "Amboli"
    ],
    "west_bengal": [
      "Darjeeling", "Kalimpong", "Kurseong", "Mirik"
    ],
    "sikkim": [
      "Gangtok", "Pelling", "Lachung", "Yumthang Valley"
    ]
  },
  "Lakes": {
    "kashmir": [
      "Dal Lake", "Pangong Lake", "Wular Lake", "Manasbal Lake"
    ],
    "rajasthan": [
      "Pichola Lake Udaipur", "Fateh Sagar Lake", "Pushkar Lake",
      "Sambhar Lake", "Nakki Lake Mount Abu"
    ],
    "uttarakhand": [
      "Nainital Lake", "Bhimtal Lake", "Sattal Lake", "Roopkund Lake"
    ],
    "madhya_pradesh": [
      "Bhojtal Bhopal", "Upper Lake", "Lower Lake"
    ],
    "karnataka": [
      "Ulsoor Lake Bangalore", "Pampa Sarovar Hampi", "Kaveri River Lakes"
    ],
    "tamil_nadu": [
      "Ooty Lake", "Kodaikanal Lake", "Yercaud Lake"
    ],
    "kerala": [
      "Vembanad Lake", "Periyar Lake", "Ashtamudi Lake"
    ]
  },
  "National_parks": {
    "madhya_pradesh": [
      "Kanha National Park", "Bandhavgarh National Park",
      "Pench National Park", "Satpura National Park"
    ],
    "rajasthan": [
      "Ranthambore National Park", "Sariska National Park",
      "Keoladeo National Park"
    ],
    "uttarakhand": [
      "Jim Corbett National Park", "Rajaji National Park",
      "Nanda Devi National Park", "Valley of Flowers"
    ],
    "karnataka": [
      "Bandipur National Park", "Nagarhole National Park",
      "Bannerghatta National Park"
    ],
    "assam": [
      "Kaziranga National Park", "Manas National Park"
    ],
    "west_bengal": [
      "Sundarbans National Park", "Gorumara National Park"
    ],
    "kerala": [
      "Periyar National Park", "Silent Valley National Park",
      "Eravikulam National Park"
    ]
  },
  "Palaces": {
    "rajasthan": [
      "City Palace Udaipur", "Hawa Mahal Jaipur",
      "Umaid Bhawan Palace Jodhpur", "Lake Palace Udaipur",
      "Jal Mahal Jaipur", "City Palace Jaipur"
    ],
    "karnataka": [
      "Mysore Palace", "Bangalore Palace", "Tipu Sultan's Palace"
    ],
    "maharashtra": [
      "Aga Khan Palace Pune", "Shaniwar Wada Pune"
    ],
    "west_bengal": [
      "Victoria Memorial Kolkata", "Marble Palace Kolkata"
    ],
    "hyderabad": [
      "Chowmahalla Palace", "Falaknuma Palace", "Chiran Palace"
    ]
  }
}

# Save dataset
dataset_file = f"{CACHE_PATH}/indian_destinations_curated.json"
with open(dataset_file, 'w') as f:
    json.dump(INDIAN_DESTINATIONS, f, indent=2)

print("="*80)
print("CURATED DATASET LOADED")
print("="*80)

# Print summary
total_destinations = 0
for theme, states in INDIAN_DESTINATIONS.items():
    theme_total = sum(len(dests) for dests in states.values())
    total_destinations += theme_total
    print(f"{theme}: {theme_total} destinations across {len(states)} states")

print(f"\nTotal destinations: {total_destinations}")
print("="*80)
# Out:
# ================================================================================
# CURATED DATASET LOADED
# ================================================================================
# Beach: 125 destinations across 12 states
# Temple: 51 destinations across 9 states
# Fort: 41 destinations across 8 states
# Waterfall: 43 destinations across 8 states
# HillStation: 48 destinations across 8 states
# Lakes: 25 destinations across 7 states
# National_parks: 21 destinations across 7 states
# Palaces: 16 destinations across 5 states
#
# Total destinations: 370
# ================================================================================

# %% [markdown]
# # =================================================================
#  STEP 5: SEARCH FUNCTION USING CURATED DATASET
# # =================================================================

# %%
def search_unsplash(query, per_page=10):
    """
    Search Unsplash for images

    Args:
        query: Search query (e.g., "Calangute Beach Goa India")
        per_page: Number of results (max 30)

    Returns:
        List of image data dicts
    """

    if UNSPLASH_ACCESS_KEY == "YOUR_ACCESS_KEY_HERE":
        print("ERROR: Please add your Unsplash API key first")
        return []

    url = "https://api.unsplash.com/search/photos"

    headers = {
        "Authorization": f"Client-ID {UNSPLASH_ACCESS_KEY}"
    }

    params = {
        "query": query,
        "per_page": min(per_page, 30),  # Max 30 per request
        "orientation": "landscape"
    }

    try:
        print(f"  Searching Unsplash for: '{query}'")
        response = requests.get(url, headers=headers, params=params, timeout=10)

        print(f"  API Status: {response.status_code}")

        if response.status_code == 200:
            data = response.json()
            results = data.get('results', [])

            print(f"Found {len(results)} images")

            image_data = []
            for result in results:
                image_data.append({
                    'url': result['urls']['regular'],  # Good quality, reasonable size
                    'download_url': result['links']['download'],
                    'photographer': result['user']['name'],
                    'photographer_url': result['user']['links']['html'],
                    'description': result.get('description', query),
                    'width': result['width'],
                    'height': result['height']
                })

            return image_data

        elif response.status_code == 401:
            print(" ERROR: Invalid API key")
            return []
        elif response.status_code == 403:
            print("  ERROR: Rate limit exceeded (50/hour)")
            return []
        else:
            print(f" ERROR: Status {response.status_code}")
            return []

    except Exception as e:
        print(f" Error: {e}")
        return []


print("="*80)
print("UNSPLASH SEARCH FUNCTION READY")
print("="*80)
# Out:
# ================================================================================
# UNSPLASH SEARCH FUNCTION READY
# ================================================================================

# %% [markdown]
# # =================================================================
#  STEP 6: DOWNLOAD IMAGE FUNCTION
# # =================================================================

# %%
def download_image_from_url(url, save_path, max_retries=2):
    """Download and save image from URL"""

    for attempt in range(max_retries):
        try:
            print(f"    Downloading...", end=" ")
            response = requests.get(url, timeout=15)

            if response.status_code == 200:
                img = Image.open(io.BytesIO(response.content))

                # Convert if needed
                if img.mode in ('RGBA', 'LA', 'P'):
                    img = img.convert('RGB')

                # Resize if too large
                max_size = (1920, 1920)
                if img.width > max_size[0] or img.height > max_size[1]:
                    img.thumbnail(max_size, Image.Resampling.LANCZOS)

                # Save
                img.save(save_path, 'JPEG', quality=90)
                print(f"Saved ({img.size})")
                return True
            else:
                print(f"Failed ({response.status_code})")

        except Exception as e:
            print(f"Error: {str(e)[:40]}")
            if attempt < max_retries - 1:
                time.sleep(1)

    return False


print("="*80)
print("DOWNLOAD FUNCTION READY")
print("="*80)
# Out:
# ================================================================================
# DOWNLOAD FUNCTION READY
# ================================================================================

# %% [markdown]
# # =================================================================
#  STEP 7: DOWNLOAD BY THEME AND STATE
# # =================================================================

# %%
def download_by_theme_and_state_unsplash(theme, state, images_per_destination=5,
                                         base_path=LANDMARKS_PATH):
    """
    Download destinations using Unsplash API

    Args:
        theme: Theme name (beaches, temples, etc.)
        state: State name
        images_per_destination: Images to download per destination
        base_path: Base path to save images
    """

    if theme not in INDIAN_DESTINATIONS:
        print(f"ERROR: Theme '{theme}' not found")
        print(f"Available: {', '.join(INDIAN_DESTINATIONS.keys())}")
        return

    if state not in INDIAN_DESTINATIONS[theme]:
        print(f"ERROR: State '{state}' not found")
        print(f"Available: {', '.join(INDIAN_DESTINATIONS[theme].keys())}")
        return

    destinations = INDIAN_DESTINATIONS[theme][state]

    print("\n" + "="*80)
    print(f"DOWNLOADING FROM UNSPLASH: {theme.upper()} - {state.upper()}")
    print("="*80)
    print(f"Destinations: {len(destinations)}")
    print(f"Images per destination: {images_per_destination}")
    print("="*80)

    total_downloaded = 0
    total_failed = 0
    total_no_results = 0

    for dest_idx, destination in enumerate(destinations, 1):

        print(f"\n[{dest_idx}/{len(destinations)}] {destination}")
        print("-" * 80)

        # Create search queries
        queries = [
            f"{destination} {state} India",
            f"{destination} India",
            destination
        ]

        all_images = []

        # Try different queries
        for query in queries:
            if len(all_images) >= images_per_destination:
                break

            results = search_unsplash(query, per_page=images_per_destination)
            all_images.extend(results)

            # Rate limiting
            time.sleep(1)

        if not all_images:
            print(f" No images found on Unsplash")
            total_no_results += 1
            continue

        # Remove duplicates
        seen_urls = set()
        unique_images = []
        for img in all_images:
            if img['url'] not in seen_urls:
                seen_urls.add(img['url'])
                unique_images.append(img)

        print(f" Found {len(unique_images)} unique images")

        # Clean folder name
        folder_name = destination.lower()
        folder_name = re.sub(r'[^\w\s-]', '', folder_name)
        folder_name = folder_name.replace(' ', '_')[:50]

        # Create folder
        dest_folder = f"{base_path}/{theme}/{state}/{folder_name}"
        os.makedirs(dest_folder, exist_ok=True)
        print(f"Folder: {dest_folder}")

        # Download images
        downloaded_count = 0

        for idx, img_data in enumerate(unique_images[:images_per_destination], 1):
            save_path = f"{dest_folder}/{folder_name}_{idx:03d}.jpg"

            if os.path.exists(save_path):
                print(f"  [{idx}] ✓ Already exists")
                downloaded_count += 1
                total_downloaded += 1
                continue

            print(f"  [{idx}] {img_data['photographer']}")
            print(f"    URL: {img_data['url'][:80]}...")

            if download_image_from_url(img_data['url'], save_path):
                downloaded_count += 1
                total_downloaded += 1
            else:
                total_failed += 1

            # Rate limiting
            time.sleep(1)

        print(f"\n  Downloaded: {downloaded_count}/{len(unique_images)}")

    # Final summary
    print("\n" + "="*80)
    print(f"SUMMARY: {theme.upper()} - {state.upper()}")
    print("="*80)
    print(f"Downloaded: {total_downloaded} images")
    print(f"Failed: {total_failed}")
    print(f"No results: {total_no_results} destinations")
    print(f" Saved to: {base_path}/{theme}/{state}/")
    print("="*80)


print("="*80)
print("UNSPLASH DOWNLOAD FUNCTION READY")
print("="*80)
# Out:
# ================================================================================
# UNSPLASH DOWNLOAD FUNCTION READY
# ================================================================================

# %% [markdown]
# # =================================================================
#   STEP 8: BATCH DOWNLOAD FUNCTION
# # =================================================================

# %%
def batch_download_unsplash(theme_state_list, images_per_destination=10):
    """
    Download multiple theme-state combinations

    Args:
        theme_state_list: List of (theme, state) tuples
        images_per_destination: Images per destination

    Example:
        batch_download_unsplash([
            ('beaches', 'goa'),
            ('temples', 'tamil_nadu'),
            ('forts', 'rajasthan')
        ], images_per_destination=5)
    """

    print("="*80)
    print("BATCH DOWNLOAD FROM UNSPLASH")
    print("="*80)
    print(f"Combinations: {len(theme_state_list)}")
    print("="*80)

    for idx, (theme, state) in enumerate(theme_state_list, 1):
        print(f"\n[{idx}/{len(theme_state_list)}] Processing: {theme} - {state}")

        download_by_theme_and_state_unsplash(
            theme=theme,
            state=state,
            images_per_destination=images_per_destination
        )

        # Delay between states to respect rate limits
        if idx < len(theme_state_list):
            print("\nWaiting 5 seconds before next batch...")
            time.sleep(5)

    print("\n" + "="*80)
    print("BATCH DOWNLOAD COMPLETE")
    print("="*80)


print("="*80)
print("BATCH DOWNLOAD FUNCTION READY")
print("="*80)
# Out:
# ================================================================================
# BATCH DOWNLOAD FUNCTION READY
# ================================================================================

# %% [markdown]
# #  =================================================================
#  STEP 9: CREATE METADATA (UPDATED FOR CLIP INTEGRATION)
# #  =================================================================

# %%
# ============================================================================
# CELL 9: CREATE METADATA (UPDATED FOR CLIP INTEGRATION)
# ============================================================================

def create_metadata(base_path=LANDMARKS_PATH):
    """Generate metadata.json compatible with CLIP prompt library"""

    metadata = {
        "version": "1.0",
        "created_date": "2026-02-14",
        "source": "Unsplash API",
        "license": "Unsplash License (Free to use)",
        "dataset": "Indian Travel Destinations",
        "clip_prompt_library": "clip_prompts_india_themes_semantic.json",
        "prompt_categories": [
            "LandscapeType", "RegionalStyle", "Atmosphere", "VisualQuality",
            "CrowdDensity", "NaturalVsCultural", "WaterFeatures",
            "VegetationType", "Accessibility", "Activities", "EconomyBudget"
        ],
        "themes": []
    }

    total_images = 0
    total_destinations = 0

    for theme in sorted(os.listdir(base_path)):
        theme_path = os.path.join(base_path, theme)

        if not os.path.isdir(theme_path) or theme.startswith('.'):
            continue

        theme_data = {
            "theme_name": theme,
            "theme_type": theme,  # Beach, Temple, Waterfall, HillStation
            "states": []
        }

        for state in sorted(os.listdir(theme_path)):
            state_path = os.path.join(theme_path, state)

            if not os.path.isdir(state_path) or state.startswith('.'):
                continue

            state_data = {
                "state_name": state,
                "destinations": []
            }

            for destination in sorted(os.listdir(state_path)):
                dest_path = os.path.join(state_path, destination)

                if not os.path.isdir(dest_path) or destination.startswith('.'):
                    continue

                images = sorted([f for f in os.listdir(dest_path)
                               if f.endswith(('.jpg', '.jpeg', '.png'))])

                if images:
                    # Create destination ID
                    dest_id = f"{theme.upper()}_{state.upper()}_{destination.upper()}"
                    dest_id = dest_id.replace(' ', '_').replace('-', '_')

                    dest_data = {
                        "destination_id": dest_id,
                        "destination_name": destination.replace('_', ' ').title(),
                        "theme": theme,
                        "state": state,
                        "folder": f"{theme}/{state}/{destination}",
                        "folder_path": f"{base_path}/{theme}/{state}/{destination}",
                        "images": images,
                        "image_count": len(images),

                        # Placeholders for VL Encoding Layer
                        "embeddings_computed": False,
                        "prompts_extracted": False,
                        "geo_tagged": False,

                        # Placeholder for geo-location
                        "geo_location": {
                            "latitude": None,
                            "longitude": None,
                            "city": None,
                            "region": None
                        },

                        # Placeholder for offers
                        "offers": {
                            "hotels": [],
                            "activities": [],
                            "flights": [],
                            "packages": []
                        }
                    }

                    state_data["destinations"].append(dest_data)
                    total_images += len(images)
                    total_destinations += 1

            if state_data["destinations"]:
                theme_data["states"].append(state_data)

        if theme_data["states"]:
            metadata["themes"].append(theme_data)

    metadata["total_themes"] = len(metadata["themes"])
    metadata["total_destinations"] = total_destinations
    metadata["total_images"] = total_images

    # Save
    metadata_path = f"{base_path}/metadata.json"
    with open(metadata_path, 'w') as f:
        json.dump(metadata, f, indent=2)

    print("="*80)
    print("METADATA CREATED")
    print("="*80)
    print(f"Themes: {metadata['total_themes']}")
    print(f"Destinations: {metadata['total_destinations']}")
    print(f"Total images: {metadata['total_images']}")
    print(f"Saved to: {metadata_path}")
    print("="*80)

    return metadata

# %% [markdown]
# =================================================================
#
# STEP 11: DOWNLOAD IMAGES  FOR THEMES: BEACHES, WATERFALLS,
#    HILLSTATIONS AND TEMPLES
#
# =================================================================

# %%
# MINIMAL DOWNLOAD (Quick test - ~40 destinations, ~200 images)
minimal_download = [
    ('Beach', 'goa'),              # 8 beaches
    ('Temple', 'tamil_nadu'),      # 4 temples
    ('Waterfall', 'karnataka'),    # 3 waterfalls
    ('HillStation', 'himachal_pradesh')  # 4 hill stations
]

# RECOMMENDED DOWNLOAD (~60 destinations, ~300 images)
recommended_download = [
    # Beaches (20 destinations)
    ('Beach', 'goa'),
    ('Beach', 'kerala'),
    ('Beach', 'maharashtra'),

    # Temples (13 destinations)
    ('Temple', 'tamil_nadu'),
    ('Temple', 'kerala'),
    ('Temple', 'karnataka'),

    # Waterfalls (11 destinations)
    ('Waterfall', 'karnataka'),
    ('Waterfall', 'kerala'),
    ('Waterfall', 'maharashtra'),

    # Hill Stations (14 destinations)
    ('HillStation', 'himachal_pradesh'),
    ('HillStation', 'uttarakhand'),
    ('HillStation', 'tamil_nadu')
]

# FULL DOWNLOAD (All states, ~70 destinations, ~350 images)
full_download = [
    # All Beaches
    ('Beach', 'goa'),
    ('Beach', 'kerala'),
    ('Beach', 'maharashtra'),
    ('Beach', 'tamil_nadu'),
    ('Beach', 'karnataka'),

    # All Temples
    ('Temple', 'tamil_nadu'),
    ('Temple', 'kerala'),
    ('Temple', 'karnataka'),
    ('Temple', 'andhra_pradesh'),

    # All Waterfalls
    ('Waterfall', 'karnataka'),
    ('Waterfall', 'kerala'),
    ('Waterfall', 'maharashtra'),
    ('Waterfall', 'meghalaya'),

    # All Hill Stations
    ('HillStation', 'himachal_pradesh'),
    ('HillStation', 'uttarakhand'),
    ('HillStation', 'tamil_nadu'),
    ('HillStation', 'kerala')
]

all_beaches = [
    ('Beach', 'goa'),
    ('Beach', 'kerala'),
    ('Beach', 'maharashtra'),
    ('Beach', 'tamil_nadu'),
    ('Beach', 'karnataka')
]
print("="*80)
print("="*80)

print("\n3. ALL BEACHES")
print(" batch_download_unsplash(all_beaches, images_per_destination=5)")

print("\n" + "="*80)

batch_download_unsplash(all_beaches, images_per_destination=5)

create_metadata()
# Out:
# ================================================================================
# ================================================================================
#
# 3. ALL BEACHES
#  batch_download_unsplash(all_beaches, images_per_destination=5)
#
# ================================================================================
# ================================================================================
# BATCH DOWNLOAD FROM UNSPLASH
# ================================================================================
# Combinations: 5
# ================================================================================
#
# [1/5] Processing: Beach - goa
#
# ================================================================================
# DOWNLOADING FROM UNSPLASH: BEACH - GOA
# ================================================================================
# Destinations: 12
# Images per destination: 5
# ================================================================================
#
# [1/12] Candolim Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Candolim Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/candolim_beach
#   [1] Joydeep Sensarma
#     URL: https://images.unsplash.com/photo-1653975725948-0983735da034?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 718))
#   [2] Dipti Goyal
#     URL: https://images.unsplash.com/photo-1663659763040-e9774bec2285?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [3] Hamza Shaikh
#     URL: https://images.unsplash.com/photo-1584111728495-7d9599602355?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 607))
#   [4] Maria Melnyk
#     URL: https://images.unsplash.com/photo-1654860242992-09132ec01ada?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [5] Maria Melnyk
#     URL: https://images.unsplash.com/photo-1654860239990-5eb21d6ced44?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 607))
#
#   Downloaded: 5/5
#
# [2/12] Benaulim Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Benaulim Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Benaulim Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Benaulim Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [3/12] Agonda Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Agonda Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Agonda Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Agonda Beach'
#   API Status: 200
# Found 1 images
#  Found 1 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/agonda_beach
#   [1] Frederic Christian
#     URL: https://images.unsplash.com/photo-1706951323946-89e4bd340348?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#
#   Downloaded: 1/1
#
# [4/12] Ashwem Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Ashwem Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/ashwem_beach
#   [1] Sudeshna Sahoo
#     URL: https://images.unsplash.com/photo-1659874817532-88fd34e6456a?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Satish Dharmavarapu
#     URL: https://images.unsplash.com/photo-1766512774708-100fc2f98d89?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 721))
#   [3] Dpuck Joe
#     URL: https://images.unsplash.com/photo-1668262121032-a182faa218ec?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [4] Sheraz Shaikh
#     URL: https://images.unsplash.com/photo-1574792573455-9305c51aeb7d?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Vizag Explore
#     URL: https://images.unsplash.com/photo-1664373755199-9c22b902232e?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#
#   Downloaded: 5/5
#
# [5/12] Mandrem Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Mandrem Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/mandrem_beach
#   [1] Tatiana Tochilova
#     URL: https://images.unsplash.com/photo-1744448365250-9b6aa1a7e4a3?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 715))
#   [2] Satish Dharmavarapu
#     URL: https://images.unsplash.com/photo-1766512774708-100fc2f98d89?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 721))
#   [3] Sudeshna Sahoo
#     URL: https://images.unsplash.com/photo-1659874817532-88fd34e6456a?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] nuddle
#     URL: https://images.unsplash.com/photo-1723216978129-363a84f9c1bb?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 296))
#   [5] Alex Rybin
#     URL: https://images.unsplash.com/photo-1605015238494-3fffb8a5b514?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 628))
#
#   Downloaded: 5/5
#
# [6/12] Sinquerim Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Sinquerim Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Sinquerim Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Sinquerim Beach'
#   API Status: 200
# Found 3 images
#  Found 3 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/sinquerim_beach
#   [1] Allan D'souza
#     URL: https://images.unsplash.com/photo-1711185425048-bb2526f08640?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [2] Allan D'souza
#     URL: https://images.unsplash.com/photo-1711185424909-f45a20cbfae7?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [3] DR KISHAN PATEL
#     URL: https://images.unsplash.com/photo-1756797949315-c13d9e3f1301?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 3/3
#
# [7/12] Miramar Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Miramar Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Miramar Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Miramar Beach'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/miramar_beach
#   [1] Yaw Afari
#     URL: https://images.unsplash.com/photo-1647797013933-c53ac86cb997?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Reagan Parr
#     URL: https://images.unsplash.com/photo-1564974429-3d7f9eb21190?crop=entropy&cs=tinysr...
#     Downloading... Saved ((1080, 810))
#   [3] Yejiang Yang
#     URL: https://images.unsplash.com/photo-1721676171506-589f986c819e?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Gerhard Crous
#     URL: https://images.unsplash.com/photo-1572222963617-a7a60a69f463?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 709))
#   [5] blanca aguilar
#     URL: https://images.unsplash.com/photo-1676159818369-ef6151379a99?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#
#   Downloaded: 5/5
#
# [8/12] Dona Paula Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Dona Paula Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Dona Paula Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Dona Paula Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [9/12] Bogmalo Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Bogmalo Beach goa India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Bogmalo Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Bogmalo Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [10/12] Butterfly Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Butterfly Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/butterfly_beach
#   [1] Sandeep N
#     URL: https://images.unsplash.com/photo-1706806696916-2268e5676c2d?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [2] Zoshua Colah
#     URL: https://images.unsplash.com/photo-1727276883315-53b22b811f43?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Sandeep N
#     URL: https://images.unsplash.com/photo-1706806124860-652cbca8afef?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [4] Zoshua Colah
#     URL: https://images.unsplash.com/photo-1727276883889-0ae802c77a2c?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Zoshua Colah
#     URL: https://images.unsplash.com/photo-1727276886127-59576ad022d3?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [11/12] Kakolem Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kakolem Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/kakolem_beach
#   [1] Satish Dharmavarapu
#     URL: https://images.unsplash.com/photo-1766512774708-100fc2f98d89?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 721))
#   [2] Sudeshna Sahoo
#     URL: https://images.unsplash.com/photo-1659874817532-88fd34e6456a?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Tojo Basu
#     URL: https://images.unsplash.com/photo-1762280408953-d1bfe77e79c1?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Dpuck Joe
#     URL: https://images.unsplash.com/photo-1668262121032-a182faa218ec?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [5] Tojo Basu
#     URL: https://images.unsplash.com/photo-1762280408876-196488a23fa0?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [12/12] Betalbatim Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Betalbatim Beach goa India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/betalbatim_beach
#   [1] Alex Rybin
#     URL: https://images.unsplash.com/photo-1605015238494-3fffb8a5b514?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 628))
#   [2] nuddle
#     URL: https://images.unsplash.com/photo-1723216978129-363a84f9c1bb?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 296))
#   [3] Dpuck Joe
#     URL: https://images.unsplash.com/photo-1668262121032-a182faa218ec?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [4] Manoj Birhade
#     URL: https://images.unsplash.com/photo-1586358762831-d5aa8502d925?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [5] Zoshua Colah
#     URL: https://images.unsplash.com/photo-1709623244505-da3f9ea63984?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# ================================================================================
# SUMMARY: BEACH - GOA
# ================================================================================
# Downloaded: 39 images
# Failed: 0
# No results: 3 destinations
#  Saved to: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/
# ================================================================================
#
# Waiting 5 seconds before next batch...
#
# [2/5] Processing: Beach - kerala
#
# ================================================================================
# DOWNLOADING FROM UNSPLASH: BEACH - KERALA
# ================================================================================
# Destinations: 15
# Images per destination: 5
# ================================================================================
#
# [1/15] Kovalam Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kovalam Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kovalam_beach
#   [1] SHILPA
#     URL: https://images.unsplash.com/photo-1718112561998-a2d2b4310f6b?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Kingsuk Pasari
#     URL: https://images.unsplash.com/photo-1681334473902-c405d28370a6?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Daniel Joshua
#     URL: https://images.unsplash.com/photo-1573269347806-8fc50039a6b5?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [4] Mohamed Adil
#     URL: https://images.unsplash.com/photo-1688312641042-82c6c914a4be?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Daniel Joshua
#     URL: https://images.unsplash.com/photo-1573269354259-8c108692afa1?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [2/15] Varkala Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Varkala Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/varkala_beach
#   [1] Abhinav Singh
#     URL: https://images.unsplash.com/photo-1739950324092-995e80d6ad34?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 607))
#   [2] Sandip Jana
#     URL: https://images.unsplash.com/photo-1766404891610-533f67fd2c19?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 672))
#   [3] Meghna Rawat
#     URL: https://images.unsplash.com/photo-1706408528840-5c688f977ff5?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [4] Mayur Arvind
#     URL: https://images.unsplash.com/photo-1709466852491-46d93466179f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Dileep M
#     URL: https://images.unsplash.com/photo-1605332324753-afda24d8e4e6?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [3/15] Cherai Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Cherai Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/cherai_beach
#   [1] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1720086301610-ad904557921f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Mayur Arvind
#     URL: https://images.unsplash.com/photo-1709466852491-46d93466179f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1718796764127-6cacd396545f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1719218245855-833c891cdbda?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Rishi Sreekar
#     URL: https://images.unsplash.com/photo-1716142602429-a61e4f08b391?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 706))
#
#   Downloaded: 5/5
#
# [4/15] Marari Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Marari Beach kerala India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Marari Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Marari Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [5/15] Bekal Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Bekal Beach kerala India'
#   API Status: 200
# Found 4 images
#   Searching Unsplash for: 'Bekal Beach India'
#   API Status: 200
# Found 5 images
#  Found 9 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/bekal_beach
#   [1] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1698070010241-1ac4d4273dff?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1698070010730-6e0b7483a78b?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1698070282418-b9ab10cd165e?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1737955658456-5b461b94dd0f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1737955658456-58ca29b3f93f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/9
#
# [6/15] Muzhappilangad Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Muzhappilangad Beach kerala India'
#   API Status: 200
# Found 2 images
#   Searching Unsplash for: 'Muzhappilangad Beach India'
#   API Status: 200
# Found 4 images
#  Found 6 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/muzhappilangad_beach
#   [1] Kishor Kumar C K
#     URL: https://images.unsplash.com/photo-1681720733081-0930b2c8212f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 419))
#   [2] Manas Manikoth
#     URL: https://images.unsplash.com/photo-1714832088101-fe98ca627955?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [3] Prabin Pradeep
#     URL: https://images.unsplash.com/photo-1630171011805-11ebc32f7229?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [4] Sooraj Varma Vk
#     URL: https://images.unsplash.com/photo-1700588990314-d8f7e1439c7b?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 615))
#   [5] Kishor Kumar C K
#     URL: https://images.unsplash.com/photo-1681720733081-0930b2c8212f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 419))
#
#   Downloaded: 5/6
#
# [7/15] Kappad Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kappad Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kappad_beach
#   [1] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1720086301610-ad904557921f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Mayur Arvind
#     URL: https://images.unsplash.com/photo-1709466852491-46d93466179f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1718796764127-6cacd396545f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1719218245855-833c891cdbda?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Daniel Pell
#     URL: https://images.unsplash.com/photo-1741387863956-801156a94c39?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [8/15] Shanghumukham Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Shanghumukham Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/shanghumukham_beach
#   [1] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1720086301610-ad904557921f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Mayur Arvind
#     URL: https://images.unsplash.com/photo-1709466852491-46d93466179f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1719218245855-833c891cdbda?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Mohamed Adil
#     URL: https://images.unsplash.com/photo-1688714848313-83243f7b504b?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Nakkeeran Raveendran
#     URL: https://images.unsplash.com/photo-1668518891186-c07180869132?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 659))
#
#   Downloaded: 5/5
#
# [9/15] Alappuzha Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Alappuzha Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/alappuzha_beach
#   [1] Sandip Jana
#     URL: https://images.unsplash.com/photo-1766404891707-65fdf69863e9?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 672))
#   [2] Jay Shah
#     URL: https://images.unsplash.com/photo-1621713745398-28bb5b45b223?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [3] Swastik Arora
#     URL: https://images.unsplash.com/photo-1704365159740-ab1f3556044a?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [4] Swastik Arora
#     URL: https://images.unsplash.com/photo-1704365159814-9d124e3cf952?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [5] Swastik Arora
#     URL: https://images.unsplash.com/photo-1704365159871-6bf63f00b9c8?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#
#   Downloaded: 5/5
#
# [10/15] Payyambalam Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Payyambalam Beach kerala India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Payyambalam Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Payyambalam Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [11/15] Kollam Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kollam Beach kerala India'
#   API Status: 200
# Found 5 images
#  Found 5 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kollam_beach
#   [1] Medha Rajeev
#     URL: https://images.unsplash.com/photo-1744958023911-aa7f2dc9121f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 608))
#   [2] Shahaan Ahmed
#     URL: https://images.unsplash.com/photo-1755116295140-1e5eec37d251?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [3] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1720086301610-ad904557921f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [4] Mayur Arvind
#     URL: https://images.unsplash.com/photo-1709466852491-46d93466179f?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Praswin Prakashan
#     URL: https://images.unsplash.com/photo-1719218245855-833c891cdbda?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/5
#
# [12/15] Kozhikode Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kozhikode Beach kerala India'
#   API Status: 200
# Found 2 images
#   Searching Unsplash for: 'Kozhikode Beach India'
#   API Status: 200
# Found 5 images
#  Found 7 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kozhikode_beach
#   [1] Dileep Kuriyedath
#     URL: https://images.unsplash.com/photo-1653280459455-d61c6f7e9e3d?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [2] Nidhin K S
#     URL: https://images.unsplash.com/photo-1678780910715-9592ca6d2098?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 680))
#   [3] Lynn
#     URL: https://images.unsplash.com/photo-1694931537831-df7efcac39a0?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 810))
#   [4] Ithal Nadi
#     URL: https://images.unsplash.com/photo-1730351129344-0303c73a7d12?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#   [5] Arun Geetha Viswanathan
#     URL: https://images.unsplash.com/photo-1620758660864-93db6324ffbb?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 720))
#
#   Downloaded: 5/7
#
# [13/15] Thirumullavaram Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Thirumullavaram Beach kerala India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Thirumullavaram Beach India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Thirumullavaram Beach'
#   API Status: 200
# Found 0 images
#  No images found on Unsplash
#
# [14/15] Kappil Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kappil Beach kerala India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Kappil Beach India'
#   API Status: 200
# Found 1 images
#   Searching Unsplash for: 'Kappil Beach'
#   API Status: 200
# Found 1 images
#  Found 2 unique images
# Folder: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kappil_beach
#   [1] Rahul Chakraborty
#     URL: https://images.unsplash.com/photo-1587033354805-2159a16a58a6?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 750))
#   [2] Rahul Chakraborty
#     URL: https://images.unsplash.com/photo-1587033354805-2159a16a58a6?crop=entropy&cs=tin...
#     Downloading... Saved ((1080, 750))
#
#   Downloaded: 2/2
#
# [15/15] Ezhimala Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Ezhimala Beach kerala India'
#   API Status: 200
# Found 0 images
#   Searching Unsplash for: 'Ezhimala Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Ezhimala Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# ================================================================================
# SUMMARY: BEACH - KERALA
# ================================================================================
# Downloaded: 52 images
# Failed: 0
# No results: 4 destinations
#  Saved to: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/
# ================================================================================
#
# Waiting 5 seconds before next batch...
#
# [3/5] Processing: Beach - maharashtra
#
# ================================================================================
# DOWNLOADING FROM UNSPLASH: BEACH - MAHARASHTRA
# ================================================================================
# Destinations: 18
# Images per destination: 5
# ================================================================================
#
# [1/18] Alibaug Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Alibaug Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Alibaug Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Alibaug Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [2/18] Kashid Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Kashid Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Kashid Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Kashid Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [3/18] Ganpatipule Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Ganpatipule Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Ganpatipule Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Ganpatipule Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [4/18] Tarkarli Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Tarkarli Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Tarkarli Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Tarkarli Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [5/18] Juhu Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Juhu Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Juhu Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Juhu Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [6/18] Girgaon Chowpatty
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Girgaon Chowpatty maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Girgaon Chowpatty India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Girgaon Chowpatty'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [7/18] Aksa Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Aksa Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Aksa Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Aksa Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [8/18] Murud Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Murud Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Murud Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Murud Beach'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#  No images found on Unsplash
#
# [9/18] Diveagar Beach
# --------------------------------------------------------------------------------
#   Searching Unsplash for: 'Diveagar Beach maharashtra India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
#   Searching Unsplash for: 'Diveagar Beach India'
#   API Status: 403
#   ERROR: Rate limit exceeded (50/hour)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3539356248.py in <cell line: 0>()
#      73 print("\n" + "="*80)
#      74
# ---> 75 batch_download_unsplash(all_beaches, images_per_destination=5)
#      76
#      77 create_metadata()
#
# /tmp/ipython-input-3054063354.py in batch_download_unsplash(theme_state_list, images_per_destination)
#      24         print(f"\n[{idx}/{len(theme_state_list)}] Processing: {theme} - {state}")
#      25
# ---> 26         download_by_theme_and_state_unsplash(
#      27             theme=theme,
#      28             state=state,
#
# /tmp/ipython-input-818139480.py in download_by_theme_and_state_unsplash(theme, state, images_per_destination, base_path)
#      57
#      58             # Rate limiting
# ---> 59             time.sleep(1)
#      60
#      61         if not all_images:
#
# KeyboardInterrupt:

# %%
create_metadata()
# Out:
# ================================================================================
# METADATA CREATED
# ================================================================================
# Themes: 1
# Destinations: 28
# Total images: 130
# Saved to: /content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/metadata.json
# ================================================================================
# {'version': '1.0',
#  'created_date': '2026-02-14',
#  'source': 'Unsplash API',
#  'license': 'Unsplash License (Free to use)',
#  'dataset': 'Indian Travel Destinations',
#  'clip_prompt_library': 'clip_prompts_india_themes_semantic.json',
#  'prompt_categories': ['LandscapeType',
#   'RegionalStyle',
#   'Atmosphere',
#   'VisualQuality',
#   'CrowdDensity',
#   'NaturalVsCultural',
#   'WaterFeatures',
#   'VegetationType',
#   'Accessibility',
#   'Activities',
#   'EconomyBudget'],
#  'themes': [{'theme_name': 'Beach',
#    'theme_type': 'Beach',
#    'states': [{'state_name': 'goa',
#      'destinations': [{'destination_id': 'BEACH_GOA_AGONDA_BEACH',
#        'destination_name': 'Agonda Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/agonda_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/agonda_beach',
#        'images': ['agonda_beach_001.jpg'],
#        'image_count': 1,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_ANJUNA_BEACH',
#        'destination_name': 'Anjuna Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/anjuna_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/anjuna_beach',
#        'images': ['anjuna_beach_001.jpg',
#         'anjuna_beach_002.jpg',
#         'anjuna_beach_003.jpg',
#         'anjuna_beach_004.jpg',
#         'anjuna_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_ARAMBOL_BEACH',
#        'destination_name': 'Arambol Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/arambol_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/arambol_beach',
#        'images': ['arambol_beach_001.jpg',
#         'arambol_beach_002.jpg',
#         'arambol_beach_003.jpg',
#         'arambol_beach_004.jpg',
#         'arambol_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_ASHWEM_BEACH',
#        'destination_name': 'Ashwem Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/ashwem_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/ashwem_beach',
#        'images': ['ashwem_beach_001.jpg',
#         'ashwem_beach_002.jpg',
#         'ashwem_beach_003.jpg',
#         'ashwem_beach_004.jpg',
#         'ashwem_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_BAGA_BEACH',
#        'destination_name': 'Baga Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/baga_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/baga_beach',
#        'images': ['baga_beach_001.jpg',
#         'baga_beach_002.jpg',
#         'baga_beach_003.jpg',
#         'baga_beach_004.jpg',
#         'baga_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_BETALBATIM_BEACH',
#        'destination_name': 'Betalbatim Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/betalbatim_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/betalbatim_beach',
#        'images': ['betalbatim_beach_001.jpg',
#         'betalbatim_beach_002.jpg',
#         'betalbatim_beach_003.jpg',
#         'betalbatim_beach_004.jpg',
#         'betalbatim_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_BUTTERFLY_BEACH',
#        'destination_name': 'Butterfly Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/butterfly_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/butterfly_beach',
#        'images': ['butterfly_beach_001.jpg',
#         'butterfly_beach_002.jpg',
#         'butterfly_beach_003.jpg',
#         'butterfly_beach_004.jpg',
#         'butterfly_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_CALANGUTE_BEACH',
#        'destination_name': 'Calangute Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/calangute_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/calangute_beach',
#        'images': ['calangute_beach_001.jpg',
#         'calangute_beach_002.jpg',
#         'calangute_beach_003.jpg',
#         'calangute_beach_004.jpg',
#         'calangute_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_CANDOLIM_BEACH',
#        'destination_name': 'Candolim Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/candolim_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/candolim_beach',
#        'images': ['candolim_beach_001.jpg',
#         'candolim_beach_002.jpg',
#         'candolim_beach_003.jpg',
#         'candolim_beach_004.jpg',
#         'candolim_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_COLVA_BEACH',
#        'destination_name': 'Colva Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/colva_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/colva_beach',
#        'images': ['colva_beach_001.jpg',
#         'colva_beach_002.jpg',
#         'colva_beach_003.jpg',
#         'colva_beach_004.jpg',
#         'colva_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_KAKOLEM_BEACH',
#        'destination_name': 'Kakolem Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/kakolem_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/kakolem_beach',
#        'images': ['kakolem_beach_001.jpg',
#         'kakolem_beach_002.jpg',
#         'kakolem_beach_003.jpg',
#         'kakolem_beach_004.jpg',
#         'kakolem_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_MANDREM_BEACH',
#        'destination_name': 'Mandrem Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/mandrem_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/mandrem_beach',
#        'images': ['mandrem_beach_001.jpg',
#         'mandrem_beach_002.jpg',
#         'mandrem_beach_003.jpg',
#         'mandrem_beach_004.jpg',
#         'mandrem_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_MIRAMAR_BEACH',
#        'destination_name': 'Miramar Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/miramar_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/miramar_beach',
#        'images': ['miramar_beach_001.jpg',
#         'miramar_beach_002.jpg',
#         'miramar_beach_003.jpg',
#         'miramar_beach_004.jpg',
#         'miramar_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_MORJIM_BEACH',
#        'destination_name': 'Morjim Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/morjim_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/morjim_beach',
#        'images': ['morjim_beach_001.jpg',
#         'morjim_beach_002.jpg',
#         'morjim_beach_003.jpg',
#         'morjim_beach_004.jpg'],
#        'image_count': 4,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_PALOLEM_BEACH',
#        'destination_name': 'Palolem Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/palolem_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/palolem_beach',
#        'images': ['palolem_beach_001.jpg',
#         'palolem_beach_002.jpg',
#         'palolem_beach_003.jpg',
#         'palolem_beach_004.jpg',
#         'palolem_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_SINQUERIM_BEACH',
#        'destination_name': 'Sinquerim Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/sinquerim_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/sinquerim_beach',
#        'images': ['sinquerim_beach_001.jpg',
#         'sinquerim_beach_002.jpg',
#         'sinquerim_beach_003.jpg'],
#        'image_count': 3,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_GOA_VAGATOR_BEACH',
#        'destination_name': 'Vagator Beach',
#        'theme': 'Beach',
#        'state': 'goa',
#        'folder': 'Beach/goa/vagator_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/goa/vagator_beach',
#        'images': ['vagator_beach_001.jpg',
#         'vagator_beach_002.jpg',
#         'vagator_beach_003.jpg',
#         'vagator_beach_004.jpg',
#         'vagator_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}}]},
#     {'state_name': 'kerala',
#      'destinations': [{'destination_id': 'BEACH_KERALA_ALAPPUZHA_BEACH',
#        'destination_name': 'Alappuzha Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/alappuzha_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/alappuzha_beach',
#        'images': ['alappuzha_beach_001.jpg',
#         'alappuzha_beach_002.jpg',
#         'alappuzha_beach_003.jpg',
#         'alappuzha_beach_004.jpg',
#         'alappuzha_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_BEKAL_BEACH',
#        'destination_name': 'Bekal Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/bekal_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/bekal_beach',
#        'images': ['bekal_beach_001.jpg',
#         'bekal_beach_002.jpg',
#         'bekal_beach_003.jpg',
#         'bekal_beach_004.jpg',
#         'bekal_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_CHERAI_BEACH',
#        'destination_name': 'Cherai Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/cherai_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/cherai_beach',
#        'images': ['cherai_beach_001.jpg',
#         'cherai_beach_002.jpg',
#         'cherai_beach_003.jpg',
#         'cherai_beach_004.jpg',
#         'cherai_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_KAPPAD_BEACH',
#        'destination_name': 'Kappad Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/kappad_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kappad_beach',
#        'images': ['kappad_beach_001.jpg',
#         'kappad_beach_002.jpg',
#         'kappad_beach_003.jpg',
#         'kappad_beach_004.jpg',
#         'kappad_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_KAPPIL_BEACH',
#        'destination_name': 'Kappil Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/kappil_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kappil_beach',
#        'images': ['kappil_beach_001.jpg', 'kappil_beach_002.jpg'],
#        'image_count': 2,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_KOLLAM_BEACH',
#        'destination_name': 'Kollam Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/kollam_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kollam_beach',
#        'images': ['kollam_beach_001.jpg',
#         'kollam_beach_002.jpg',
#         'kollam_beach_003.jpg',
#         'kollam_beach_004.jpg',
#         'kollam_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_KOVALAM_BEACH',
#        'destination_name': 'Kovalam Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/kovalam_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kovalam_beach',
#        'images': ['kovalam_beach_001.jpg',
#         'kovalam_beach_002.jpg',
#         'kovalam_beach_003.jpg',
#         'kovalam_beach_004.jpg',
#         'kovalam_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_KOZHIKODE_BEACH',
#        'destination_name': 'Kozhikode Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/kozhikode_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/kozhikode_beach',
#        'images': ['kozhikode_beach_001.jpg',
#         'kozhikode_beach_002.jpg',
#         'kozhikode_beach_003.jpg',
#         'kozhikode_beach_004.jpg',
#         'kozhikode_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_MUZHAPPILANGAD_BEACH',
#        'destination_name': 'Muzhappilangad Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/muzhappilangad_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/muzhappilangad_beach',
#        'images': ['muzhappilangad_beach_001.jpg',
#         'muzhappilangad_beach_002.jpg',
#         'muzhappilangad_beach_003.jpg',
#         'muzhappilangad_beach_004.jpg',
#         'muzhappilangad_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_SHANGHUMUKHAM_BEACH',
#        'destination_name': 'Shanghumukham Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/shanghumukham_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/shanghumukham_beach',
#        'images': ['shanghumukham_beach_001.jpg',
#         'shanghumukham_beach_002.jpg',
#         'shanghumukham_beach_003.jpg',
#         'shanghumukham_beach_004.jpg',
#         'shanghumukham_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}},
#       {'destination_id': 'BEACH_KERALA_VARKALA_BEACH',
#        'destination_name': 'Varkala Beach',
#        'theme': 'Beach',
#        'state': 'kerala',
#        'folder': 'Beach/kerala/varkala_beach',
#        'folder_path': '/content/drive/MyDrive/visual-intelligence-travel-finance/data/landmarks/Beach/kerala/varkala_beach',
#        'images': ['varkala_beach_001.jpg',
#         'varkala_beach_002.jpg',
#         'varkala_beach_003.jpg',
#         'varkala_beach_004.jpg',
#         'varkala_beach_005.jpg'],
#        'image_count': 5,
#        'embeddings_computed': False,
#        'prompts_extracted': False,
#        'geo_tagged': False,
#        'geo_location': {'latitude': None,
#         'longitude': None,
#         'city': None,
#         'region': None},
#        'offers': {'hotels': [],
#         'activities': [],
#         'flights': [],
#         'packages': []}}]}]}],
#  'total_themes': 1,
#  'total_destinations': 28,
#  'total_images': 130}
